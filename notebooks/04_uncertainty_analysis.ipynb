# %% [markdown]
# # 04 — Uncertainty Analysis
#
# Evaluating model calibration and the value of uncertainty estimates.
#
# **Questions addressed:**
# - Are model uncertainty estimates well-calibrated?
# - Does high uncertainty correlate with high prediction error?
# - If we refuse to predict on uncertain compounds, how much does accuracy improve?
# - Which model produces the best-calibrated uncertainty?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

# TODO: Load predictions with uncertainty estimates

# %% [markdown]
# ## Calibration Curves

# %%
# TODO: Expected vs observed coverage

# %% [markdown]
# ## Error–Uncertainty Correlation

# %%
# TODO: Scatter |error| vs uncertainty

# %% [markdown]
# ## Selective Prediction

# %%
# TODO: RMSE vs retention fraction curve
