# %% [markdown]
# # 01 — Data Audit
#
# Exploratory analysis of the curated kinase bioactivity dataset.
#
# **Questions addressed:**
# - How many compounds, targets, and measurements are in the dataset?
# - What is the distribution of pActivity values?
# - How is target coverage distributed (measurements per kinase)?
# - What is the chemical diversity (scaffold distribution)?
# - How many compounds are flagged as noisy?
# - What are the class balance statistics per split?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

# TODO: Load curated dataset
# df = pd.read_parquet("../data/processed/v1/curated_activities.parquet")

# %% [markdown]
# ## Dataset Overview

# %%
# TODO: Dataset size statistics

# %% [markdown]
# ## Activity Distribution

# %%
# TODO: pActivity histogram

# %% [markdown]
# ## Target Coverage

# %%
# TODO: Measurements per kinase bar chart

# %% [markdown]
# ## Chemical Diversity

# %%
# TODO: Scaffold distribution analysis

# %% [markdown]
# ## Data Quality

# %%
# TODO: Noisy measurement analysis

# %% [markdown]
# ## Split Statistics

# %%
# TODO: Class balance per split
