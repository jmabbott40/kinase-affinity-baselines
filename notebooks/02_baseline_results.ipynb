# %% [markdown]
# # 02 — Baseline Model Results
#
# Comparison of baseline models across splitting strategies.
#
# **Questions addressed:**
# - Which baseline model performs best for pActivity prediction?
# - How much does performance degrade from random → scaffold → target split?
# - What features are most important for each model?
# - Are there systematic prediction biases?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

# TODO: Load results from results/tables/

# %% [markdown]
# ## Model Comparison Table

# %%
# TODO: RMSE, MAE, R², Pearson R, Spearman ρ per model × split

# %% [markdown]
# ## Predicted vs Actual

# %%
# TODO: Scatter plots per model

# %% [markdown]
# ## Split Performance Degradation

# %%
# TODO: Bar chart showing performance drop across splits

# %% [markdown]
# ## Feature Importance

# %%
# TODO: Top features for tree-based models
