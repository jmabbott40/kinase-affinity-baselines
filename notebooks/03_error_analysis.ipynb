# %% [markdown]
# # 03 — Error Analysis
#
# Understanding when and why models fail.
#
# **Questions addressed:**
# - What are the worst-predicted compounds? What makes them hard?
# - Are activity cliffs responsible for large errors?
# - Which kinase targets are harder to predict?
# - Are noisy compounds (high measurement variance) harder to predict?
# - What are common false positives and false negatives?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

# TODO: Load predictions and dataset

# %% [markdown]
# ## Worst Predictions

# %%
# TODO: Analyze worst-predicted compounds

# %% [markdown]
# ## Per-Target Error Breakdown

# %%
# TODO: RMSE by kinase target

# %% [markdown]
# ## Noise Impact

# %%
# TODO: Compare performance on clean vs noisy compounds
